# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="darkgrid")
import scipy as sp
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from datetime import datetime
import shap

# %%
exec(open("../../header.py").read())

# %% [markdown]
# # Import data

# %%
X = pd.read_csv(processed_root('cervical_cancer_risks/X.csv'))
y = pd.read_csv(processed_root('cervical_cancer_risks/y.csv'))

# %% [markdown]
# # Fit model

# %%
# fit RF
rf = RandomForestClassifier(n_estimators = 500)
rf.fit(X, y['Biopsy'])
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# # Shapley Values

# %%
shap_values = shap.TreeExplainer(rf).shap_values(X)
shap.summary_plot(shap_values[1], X, plot_type = "bar")

# %%
features = X.columns
vals = np.abs(shap_values[1]).mean(0)
shap_vals = pd.DataFrame(list(zip(features, vals)), columns=['Feature','Shap_Value'])
shap_vals.sort_values(by=['Shap_Value'], ascending=False,inplace=True)
shap_vals.head(20)
# Out:
#                                Feature  Shap_Value
# 8      Hormonal Contraceptives (years)    0.020074
# 3                   Num of pregnancies    0.014428
# 0                                  Age    0.014209
# 1            Number of sexual partners    0.012434
# 2             First sexual intercourse    0.012273
# 7              Hormonal Contraceptives    0.008062
# 31                                  Dx    0.005146
# 6                  Smokes (packs/year)    0.005014
# 28                           Dx:Cancer    0.004460
# 30                              Dx:HPV    0.004133
# 10                         IUD (years)    0.003792
# 9                                  IUD    0.003305
# 5                       Smokes (years)    0.003283
# 12                       STDs (number)    0.003123
# 22                            STDs:HIV    0.003107
# 26    STDs: Time since first diagnosis    0.002980
# 29                              Dx:CIN    0.002391
# 27     STDs: Time since last diagnosis    0.002362
# 16  STDs:vulvo-perineal condylomatosis    0.002360
# 11                                STDs    0.002352

# %% [markdown]
# # Age plot

# %%
exec(open("../../header.py").read())

# %%
ice = ICE("binary", trace = False)

# %%
ice.fit_single_feature(X, rf, "Age")
# Out:
# Fit Age in 2.32 seconds

# %%
ice.ice_plot_single_feature('Age', plot_num = 200, mode = "ice", 
    save_path = results_root('cancer-dataset-production/age-ice.pdf'))
# Out:
# Preprocessed data in 0.05 seconds
# Plotted in 0.76 seconds

# %% [markdown]
# # Fit all

# %%
ice.fit(X, rf)
# Out:
# Fit Age in 2.14 seconds
# Fit Number of sexual partners in 1.62 seconds
# Fit First sexual intercourse in 1.78 seconds
# Fit Num of pregnancies in 1.69 seconds
# Fit Smokes in 1.37 seconds
# Fit Smokes (years) in 1.95 seconds
# Fit Smokes (packs/year) in 2.79 seconds
# Fit Hormonal Contraceptives in 1.52 seconds
# Fit Hormonal Contraceptives (years) in 2.22 seconds
# Fit IUD in 1.47 seconds
# Fit IUD (years) in 1.87 seconds
# Fit STDs in 1.41 seconds
# Fit STDs (number) in 1.40 seconds
# Fit STDs:condylomatosis in 1.34 seconds
# Fit STDs:cervical condylomatosis in 1.37 seconds
# Fit STDs:vaginal condylomatosis in 1.38 seconds
# Fit STDs:vulvo-perineal condylomatosis in 1.30 seconds
# Fit STDs:syphilis in 1.30 seconds
# Fit STDs:pelvic inflammatory disease in 1.30 seconds
# Fit STDs:genital herpes in 1.33 seconds
# Fit STDs:molluscum contagiosum in 1.32 seconds
# Fit STDs:AIDS in 1.23 seconds
# Fit STDs:HIV in 1.34 seconds
# Fit STDs:Hepatitis B in 1.28 seconds
# Fit STDs:HPV in 1.28 seconds
# Fit STDs: Number of diagnosis in 1.32 seconds
# Fit STDs: Time since first diagnosis in 1.66 seconds
# Fit STDs: Time since last diagnosis in 1.60 seconds
# Fit Dx:Cancer in 1.28 seconds
# Fit Dx:CIN in 1.32 seconds
# Fit Dx:HPV in 1.25 seconds
# Fit Dx in 1.27 seconds

# %% [markdown]
# # Full ICE plot

# %%
ice.ice_plot(save_path = results_root('cancer-dataset-production/all-ice-plots.pdf'),
             mode = 'ice', ncols = 4)
# ice.ice_plot(mode = "ice")

# %%
# ice.ice_plot(results_root("ice-plot-from-class/all_plots.pdf"))
ice.ice_plot(save_path = results_root('cancer-dataset-production/all-c-ice-plots.pdf'),
             mode = 'c-ice')

# %%
# ice.ice_plot(results_root("ice-plot-from-class/all_plots.pdf"))
ice.ice_plot(save_path = results_root('cancer-dataset-production/all-d-ice-plots.pdf'),
             mode = 'd-ice')

# %% [markdown]
# # Feature impact histogram

# %%
ice.feature_impact_hist(results_root("cancer-dataset-production/fi_histograms.pdf"))

# %% [markdown]
# # Feature impact vs Shapley values

# %%
ice.feature_impact_table()\
    .merge(shap_vals, how = "inner", on = "Feature")\
    .assign(Difference = lambda x:x['Normalized Feature Impact'] - x['Shap_Value'],
            in_dist_difference = lambda x:x['Normalized In-Dist Feature Impact'] - x['Shap_Value'])\
    .rename({'in_dist_difference':'In-Dist Difference'}, axis = 1)\
    .round(2)\
    .sort_values('Difference', ascending = False)
# Out:
#                                Feature  Feature Impact  \
# 19                 STDs:genital herpes            2.71
# 20          STDs:molluscum contagiosum            2.40
# 23                    STDs:Hepatitis B            2.09
# 24                            STDs:HPV            1.19
# 18    STDs:pelvic inflammatory disease            1.16
# 2             First sexual intercourse            0.81
# 15         STDs:vaginal condylomatosis            0.65
# 6                  Smokes (packs/year)            0.41
# 8      Hormonal Contraceptives (years)            0.41
# 10                         IUD (years)            0.23
# 0                                  Age            0.15
# 22                            STDs:HIV            0.11
# 5                       Smokes (years)            0.11
# 1            Number of sexual partners            0.09
# 31                                  Dx            0.08
# 3                   Num of pregnancies            0.08
# 28                           Dx:Cancer            0.08
# 9                                  IUD            0.07
# 29                              Dx:CIN            0.07
# 17                       STDs:syphilis            0.07
# 30                              Dx:HPV            0.06
# 16  STDs:vulvo-perineal condylomatosis            0.04
# 13                 STDs:condylomatosis            0.03
# 26    STDs: Time since first diagnosis            0.03
# 12                       STDs (number)            0.03
# 27     STDs: Time since last diagnosis            0.03
# 4                               Smokes            0.02
# 7              Hormonal Contraceptives            0.02
# 11                                STDs            0.02
# 25           STDs: Number of diagnosis            0.01
# 21                           STDs:AIDS            0.00
# 14        STDs:cervical condylomatosis            0.00
#
#     In-Dist Feature Impact  Normalized Feature Impact  \
# 19                    2.38                      20.47
# 20                    2.13                      18.11
# 23                    1.85                      15.76
# 24                    1.06                       8.98
# 18                    1.03                       8.74
# 2                     0.89                       6.13
# 15                    0.58                       4.90
# 6                     0.44                       3.13
# 8                     0.43                       3.08
# 10                    0.26                       1.76
# 0                     0.15                       1.11
# 22                    0.09                       0.82
# 5                     0.11                       0.81
# 1                     0.10                       0.70
# 31                    0.02                       0.60
# 3                     0.09                       0.59
# 28                    0.02                       0.58
# 9                     0.06                       0.53
# 29                    0.01                       0.52
# 17                    0.06                       0.50
# 30                    0.01                       0.46
# 16                    0.03                       0.31
# 13                    0.02                       0.26
# 26                    0.03                       0.22
# 12                    0.03                       0.23
# 27                    0.03                       0.20
# 4                     0.02                       0.18
# 7                     0.01                       0.13
# 11                    0.01                       0.13
# 25                    0.01                       0.06
# 21                    0.00                       0.00
# 14                    0.00                       0.00
#
#     Normalized In-Dist Feature Impact  Shap_Value  Difference  \
# 19                              19.97        0.00       20.47
# 20                              17.85        0.00       18.11
# 23                              15.53        0.00       15.76
# 24                               8.85        0.00        8.98
# 18                               8.61        0.00        8.74
# 2                                7.46        0.01        6.12
# 15                               4.82        0.00        4.90
# 6                                3.65        0.01        3.13
# 8                                3.59        0.02        3.06
# 10                               2.19        0.00        1.76
# 0                                1.23        0.01        1.09
# 22                               0.73        0.00        0.82
# 5                                0.93        0.00        0.81
# 1                                0.81        0.01        0.69
# 31                               0.14        0.01        0.59
# 3                                0.73        0.01        0.58
# 28                               0.13        0.00        0.57
# 9                                0.48        0.00        0.53
# 29                               0.12        0.00        0.52
# 17                               0.48        0.00        0.49
# 30                               0.11        0.00        0.45
# 16                               0.24        0.00        0.31
# 13                               0.19        0.00        0.26
# 26                               0.27        0.00        0.22
# 12                               0.24        0.00        0.22
# 27                               0.24        0.00        0.20
# 4                                0.15        0.00        0.17
# 7                                0.11        0.01        0.13
# 11                               0.09        0.00        0.13
# 25                               0.06        0.00        0.06
# 21                               0.00        0.00        0.00
# 14                               0.00        0.00        0.00
#
#     In-Dist Difference
# 19               19.97
# 20               17.85
# 23               15.53
# 24                8.85
# 18                8.61
# 2                 7.45
# 15                4.82
# 6                 3.65
# 8                 3.57
# 10                2.19
# 0                 1.22
# 22                0.73
# 5                 0.93
# 1                 0.80
# 31                0.13
# 3                 0.71
# 28                0.13
# 9                 0.47
# 29                0.12
# 17                0.47
# 30                0.10
# 16                0.24
# 13                0.19
# 26                0.26
# 12                0.24
# 27                0.24
# 4                 0.14
# 7                 0.10
# 11                0.09
# 25                0.06
# 21                0.00
# 14                0.00

# %% [markdown]
# # Feature impact vs random forest feature importance

# %%
b = pd.DataFrame({'Feature':X.columns, 
              'RF Feature Importance':rf.feature_importances_*100})\
    .round(3)

# %%
a = ice.feature_impact_table()\
    .merge(b, how = "inner", on = "Feature")\
    .assign(Difference = lambda x:x['Normalized Feature Impact'] - x['RF Feature Importance'],
            in_dist_difference = lambda x:x['Normalized In-Dist Feature Impact'] - x['RF Feature Importance'])\
    .rename({'in_dist_difference':'In-Dist Difference'}, axis = 1)\
    .round(2)\
    .sort_values('Difference', ascending = False)\
    .loc[:,['Feature', 'Feature Impact', 'In-Dist Feature Impact', 'Normalized Feature Impact', 'RF Feature Importance', 'Difference']]

# %%
a.sort_values('RF Feature Importance', ascending = False)
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age            0.15
# 8      Hormonal Contraceptives (years)            0.41
# 2             First sexual intercourse            0.81
# 3                   Num of pregnancies            0.08
# 1            Number of sexual partners            0.09
# 5                       Smokes (years)            0.11
# 10                         IUD (years)            0.23
# 6                  Smokes (packs/year)            0.41
# 7              Hormonal Contraceptives            0.02
# 9                                  IUD            0.07
# 31                                  Dx            0.08
# 26    STDs: Time since first diagnosis            0.03
# 27     STDs: Time since last diagnosis            0.03
# 28                           Dx:Cancer            0.08
# 4                               Smokes            0.02
# 30                              Dx:HPV            0.06
# 22                            STDs:HIV            0.11
# 12                       STDs (number)            0.03
# 29                              Dx:CIN            0.07
# 19                 STDs:genital herpes            2.71
# 13                 STDs:condylomatosis            0.03
# 25           STDs: Number of diagnosis            0.01
# 16  STDs:vulvo-perineal condylomatosis            0.04
# 11                                STDs            0.02
# 17                       STDs:syphilis            0.07
# 15         STDs:vaginal condylomatosis            0.65
# 24                            STDs:HPV            1.19
# 23                    STDs:Hepatitis B            2.09
# 20          STDs:molluscum contagiosum            2.40
# 18    STDs:pelvic inflammatory disease            1.16
# 21                           STDs:AIDS            0.00
# 14        STDs:cervical condylomatosis            0.00
#
#     In-Dist Feature Impact  Normalized Feature Impact  RF Feature Importance  \
# 0                     0.15                       1.11                  17.82
# 8                     0.43                       3.08                  15.34
# 2                     0.89                       6.13                  12.10
# 3                     0.09                       0.59                  10.23
# 1                     0.10                       0.70                   9.74
# 5                     0.11                       0.81                   3.87
# 10                    0.26                       1.76                   3.87
# 6                     0.44                       3.13                   3.48
# 7                     0.01                       0.13                   2.67
# 9                     0.06                       0.53                   2.32
# 31                    0.02                       0.60                   1.98
# 26                    0.03                       0.22                   1.90
# 27                    0.03                       0.20                   1.82
# 28                    0.02                       0.58                   1.67
# 4                     0.02                       0.18                   1.60
# 30                    0.01                       0.46                   1.58
# 22                    0.09                       0.82                   1.22
# 12                    0.03                       0.23                   1.16
# 29                    0.01                       0.52                   1.14
# 19                    2.38                      20.47                   0.95
# 13                    0.02                       0.26                   0.64
# 25                    0.01                       0.06                   0.61
# 16                    0.03                       0.31                   0.58
# 11                    0.01                       0.13                   0.53
# 17                    0.06                       0.50                   0.31
# 15                    0.58                       4.90                   0.23
# 24                    1.06                       8.98                   0.22
# 23                    1.85                      15.76                   0.16
# 20                    2.13                      18.11                   0.15
# 18                    1.03                       8.74                   0.12
# 21                    0.00                       0.00                   0.00
# 14                    0.00                       0.00                   0.00
#
#     Difference
# 0       -16.71
# 8       -12.26
# 2        -5.97
# 3        -9.64
# 1        -9.04
# 5        -3.06
# 10       -2.10
# 6        -0.35
# 7        -2.54
# 9        -1.79
# 31       -1.38
# 26       -1.67
# 27       -1.62
# 28       -1.09
# 4        -1.42
# 30       -1.12
# 22       -0.39
# 12       -0.93
# 29       -0.61
# 19       19.52
# 13       -0.38
# 25       -0.55
# 16       -0.27
# 11       -0.40
# 17        0.18
# 15        4.66
# 24        8.76
# 23       15.60
# 20       17.96
# 18        8.63
# 21        0.00
# 14        0.00

# %%
print(a.to_latex(index = False,
                 column_format = 'p{5cm}c{1cm}c{1cm}c{1cm}c{1cm}c{1cm}',
                 label = "fig:cancer-fi-table",
                 caption = "Feature impact table for all features in cervical cancer dataset.",
                ))
# Out:
# \begin{table}
# \centering
# \caption{Feature impact table for all features in cervical cancer dataset.}
# \label{fig:cancer-fi-table}
# \begin{tabular}{p{5cm}c{1cm}c{1cm}c{1cm}c{1cm}c{1cm}}
# \toprule
# Feature &  Feature Impact &  In-Dist Feature Impact &  Normalized Feature Impact &  RF Feature Importance &  Difference \\
# \midrule
#     Age &            0.15 &                    0.15 &                      100.0 &                  17.82 &       82.18 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
print(a\
      .assign(abs_diff = lambda x:np.abs(x['Difference']))\
      .sort_values('abs_diff', ascending = False)\
      .drop('abs_diff', axis = 1)\
      .head(5)\
      .to_latex(index = False,
                 column_format = 'p{5cm}c{1cm}c{1cm}c{1cm}c{1cm}c{1cm}',
                 label = "fig:cancer-fi-table-top-5",
                 caption = "Feature impact table for features in cervical cancer dataset with largest difference between feature importance and impact.",
                ))
# Out:
# \begin{table}
# \centering
# \caption{Feature impact table for features in cervical cancer dataset with largest difference between feature importance and impact.}
# \label{fig:cancer-fi-table-top-5}
# \begin{tabular}{p{5cm}c{1cm}c{1cm}c{1cm}c{1cm}c{1cm}}
# \toprule
# Feature &  Feature Impact &  In-Dist Feature Impact &  Normalized Feature Impact &  RF Feature Importance &  Difference \\
# \midrule
#     Age &            0.15 &                    0.15 &                      100.0 &                  17.82 &       82.18 \\
# \bottomrule
# \end{tabular}
# \end{table}
