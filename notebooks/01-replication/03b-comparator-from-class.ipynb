# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="darkgrid")
import scipy as sp
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from datetime import datetime
import shap

# %%
exec(open("../../header.py").read())

# %% [markdown]
# # Import data

# %%
X = pd.read_csv(processed_root('cervical_cancer_risks/X.csv'))
y = pd.read_csv(processed_root('cervical_cancer_risks/y.csv'))

# %% [markdown]
# # Fit model

# %%
# fit RF
rf = RandomForestClassifier(n_estimators = 500)
rf.fit(X, y['Biopsy'])
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# # Shapley object

# %%
shapley = SHAP_FI()
ice = ICE("binary", trace = False)
fi_metrics = [ice, shapley]

# %%
build_comparator_table(X, rf, fi_metrics)
# Out:
# Fit Age in 4.52 seconds
# Fit Number of sexual partners in 2.90 seconds
# Fit First sexual intercourse in 3.30 seconds
# Fit Num of pregnancies in 3.24 seconds
# Fit Smokes in 2.55 seconds
# Fit Smokes (years) in 4.38 seconds
# Fit Smokes (packs/year) in 5.55 seconds
# Fit Hormonal Contraceptives in 2.60 seconds
# Fit Hormonal Contraceptives (years) in 4.84 seconds
# Fit IUD in 2.51 seconds
# Fit IUD (years) in 3.65 seconds
# Fit STDs in 2.63 seconds
# Fit STDs (number) in 2.98 seconds
# Fit STDs:condylomatosis in 2.48 seconds
# Fit STDs:cervical condylomatosis in 4.05 seconds
# Fit STDs:vaginal condylomatosis in 3.22 seconds
# Fit STDs:vulvo-perineal condylomatosis in 3.94 seconds
# Fit STDs:syphilis in 2.47 seconds
# Fit STDs:pelvic inflammatory disease in 2.54 seconds
# Fit STDs:genital herpes in 2.31 seconds
# Fit STDs:molluscum contagiosum in 2.84 seconds
# Fit STDs:AIDS in 2.80 seconds
# Fit STDs:HIV in 2.84 seconds
# Fit STDs:Hepatitis B in 2.30 seconds
# Fit STDs:HPV in 2.50 seconds
# Fit STDs: Number of diagnosis in 2.52 seconds
# Fit STDs: Time since first diagnosis in 3.52 seconds
# Fit STDs: Time since last diagnosis in 3.41 seconds
# Fit Dx:Cancer in 3.11 seconds
# Fit Dx:CIN in 2.60 seconds
# Fit Dx:HPV in 2.39 seconds
# Fit Dx in 2.28 seconds
# SHAP fits in 39.11 seconds
#                                Feature  Feature Impact  \
# 0                                  Age        0.137055
# 1            Number of sexual partners        0.090895
# 2             First sexual intercourse        0.814532
# 3                   Num of pregnancies        0.080320
# 4                               Smokes        0.026364
# 5                       Smokes (years)        0.139335
# 6                  Smokes (packs/year)        0.469242
# 7              Hormonal Contraceptives        0.018047
# 8      Hormonal Contraceptives (years)        0.478378
# 9                                  IUD        0.067049
# 10                         IUD (years)        0.267635
# 11                                STDs        0.024598
# 12                       STDs (number)        0.028883
# 13                 STDs:condylomatosis        0.041323
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        0.635440
# 16  STDs:vulvo-perineal condylomatosis        0.040265
# 17                       STDs:syphilis        0.116060
# 18    STDs:pelvic inflammatory disease        1.570274
# 19                 STDs:genital herpes        2.070671
# 20          STDs:molluscum contagiosum        1.701642
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        0.102008
# 23                    STDs:Hepatitis B        1.876382
# 24                            STDs:HPV        0.893616
# 25           STDs: Number of diagnosis        0.005876
# 26    STDs: Time since first diagnosis        0.026701
# 27     STDs: Time since last diagnosis        0.032358
# 28                           Dx:Cancer        0.070002
# 29                              Dx:CIN        0.068342
# 30                              Dx:HPV        0.056897
# 31                                  Dx        0.074239
#
#     In-Dist Feature Impact  Normalized Feature Impact  \
# 0                 0.139043                   1.139805
# 1                 0.095262                   0.755919
# 2                 0.892639                   6.773980
# 3                 0.088779                   0.667972
# 4                 0.019724                   0.219256
# 5                 0.152308                   1.158769
# 6                 0.494245                   3.902409
# 7                 0.012694                   0.150088
# 8                 0.504110                   3.978387
# 9                 0.053257                   0.557605
# 10                0.306644                   2.225757
# 11                0.017149                   0.204564
# 12                0.027227                   0.240200
# 13                0.030483                   0.343658
# 14                0.000000                   0.000000
# 15                0.563363                   5.284573
# 16                0.027928                   0.334858
# 17                0.101652                   0.965198
# 18                1.395007                  13.059036
# 19                1.812933                  17.220536
# 20                1.512076                  14.151540
# 21                0.000000                   0.000000
# 22                0.081886                   0.848337
# 23                1.667335                  15.604747
# 24                0.794038                   7.431673
# 25                0.005457                   0.048871
# 26                0.028845                   0.222056
# 27                0.034816                   0.269102
# 28                0.014759                   0.582165
# 29                0.013985                   0.568363
# 30                0.012149                   0.473179
# 31                0.015738                   0.617402
#
#     Normalized In-Dist Feature Impact  Shapley Value
# 0                            1.273806       0.014300
# 1                            0.872724       0.011929
# 2                            8.177696       0.013034
# 3                            0.813326       0.015247
# 4                            0.180697       0.002113
# 5                            1.395333       0.003565
# 6                            4.527904       0.004596
# 7                            0.116293       0.008578
# 8                            4.618284       0.020041
# 9                            0.487904       0.003035
# 10                           2.809242       0.003731
# 11                           0.157105       0.002811
# 12                           0.249434       0.003220
# 13                           0.279259       0.002008
# 14                           0.000000       0.000000
# 15                           5.161113       0.000732
# 16                           0.255855       0.002415
# 17                           0.931259       0.001569
# 18                          12.780019       0.000427
# 19                          16.608753       0.001412
# 20                          13.852521       0.000553
# 21                           0.000000       0.000000
# 22                           0.750179       0.002826
# 23                          15.274893       0.000584
# 24                           7.274386       0.000554
# 25                           0.049994       0.000961
# 26                           0.264256       0.003191
# 27                           0.318955       0.002545
# 28                           0.135209       0.004442
# 29                           0.128118       0.002372
# 30                           0.111304       0.004048
# 31                           0.144181       0.004904
