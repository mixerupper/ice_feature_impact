# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="darkgrid")
import scipy as sp
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from datetime import datetime
import shap

# %%
exec(open("../../header.py").read())

# %% [markdown]
# # Import data

# %%
X = pd.read_csv(processed_root('cervical_cancer_risks/X.csv'))
y = pd.read_csv(processed_root('cervical_cancer_risks/y.csv'))

# %% [markdown]
# # Fit model

# %%
# fit RF
rf = RandomForestClassifier(n_estimators = 500)
rf.fit(X, y['Biopsy'])
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# # Shapley object

# %%
shapley = SHAP_FI()
ice = ICE("binary", trace = False)
fi_metrics = [ice, shapley]

# %%
comparator = Comparator()

# %%
comparator.fit(X, rf, fi_metrics)
# Out:
# SHAP fits in 30.29 seconds

# %%
comparator.build_raw_table()
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age        0.139761
# 1            Number of sexual partners        0.100443
# 2             First sexual intercourse        0.874454
# 3                   Num of pregnancies        0.075411
# 4                               Smokes        0.032788
# 5                       Smokes (years)        0.141022
# 6                  Smokes (packs/year)        0.460108
# 7              Hormonal Contraceptives        0.018038
# 8      Hormonal Contraceptives (years)        0.392535
# 9                                  IUD        0.051055
# 10                         IUD (years)        0.287824
# 11                                STDs        0.017957
# 12                       STDs (number)        0.029680
# 13                 STDs:condylomatosis        0.035732
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        0.426076
# 16  STDs:vulvo-perineal condylomatosis        0.053276
# 17                       STDs:syphilis        0.106031
# 18    STDs:pelvic inflammatory disease        1.279135
# 19                 STDs:genital herpes        2.152964
# 20          STDs:molluscum contagiosum        2.019895
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        0.083410
# 23                    STDs:Hepatitis B        1.672841
# 24                            STDs:HPV        0.811968
# 25           STDs: Number of diagnosis        0.008120
# 26    STDs: Time since first diagnosis        0.027040
# 27     STDs: Time since last diagnosis        0.025580
# 28                           Dx:Cancer        0.070150
# 29                              Dx:CIN        0.078613
# 30                              Dx:HPV        0.066619
# 31                                  Dx        0.077260
#
#     In-Dist Feature Impact  Shapley Value
# 0                 0.140984       0.013974
# 1                 0.104049       0.011971
# 2                 0.963033       0.013072
# 3                 0.083556       0.013916
# 4                 0.024613       0.002337
# 5                 0.155952       0.003262
# 6                 0.481304       0.004818
# 7                 0.012798       0.008761
# 8                 0.416374       0.019721
# 9                 0.040367       0.003218
# 10                0.326308       0.004259
# 11                0.011741       0.002410
# 12                0.027342       0.002999
# 13                0.025409       0.002079
# 14                0.000000       0.000000
# 15                0.378009       0.000477
# 16                0.040497       0.002614
# 17                0.092181       0.001661
# 18                1.136547       0.000304
# 19                1.891312       0.001299
# 20                1.794488       0.000520
# 21                0.000000       0.000000
# 22                0.062972       0.003145
# 23                1.485817       0.000478
# 24                0.720913       0.000505
# 25                0.007476       0.001281
# 26                0.029171       0.003057
# 27                0.027065       0.002364
# 28                0.014738       0.004235
# 29                0.016085       0.002551
# 30                0.014144       0.004476
# 31                0.016186       0.004840

# %%
comparator.build_normalized_table()
# Out:
# Feature                   AgeNumber of sexual partnersFirst sexual inter...
# Feature Impact                                                          100
# In-Dist Feature Impact                                                  100
# Shapley Value                                                           100
# dtype: object
