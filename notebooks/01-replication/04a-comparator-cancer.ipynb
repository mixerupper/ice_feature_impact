# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="darkgrid")
import scipy as sp
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from datetime import datetime
import shap

# %%
exec(open("../../header.py").read())

# %% [markdown]
# # Import data

# %%
X = pd.read_csv(processed_root('cervical_cancer_risks/X.csv'))
y = pd.read_csv(processed_root('cervical_cancer_risks/y.csv'))

# %% [markdown]
# # Fit model

# %%
model = RandomForestClassifier(n_estimators = 500)
model.fit(X, y['Biopsy'])
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# # Shapley object

# %%
shapley = SHAP_FI()
native = Native_FI()
ice = ICE("binary", trace = False)

fi_metrics = [ice, native]

# %%
comparator = Comparator()

# %%
comparator.fit(X, model, fi_metrics)

# %%
comparator.build_raw_table()
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age        0.147237
# 1            Number of sexual partners        0.101196
# 2             First sexual intercourse        0.864574
# 3                   Num of pregnancies        0.076993
# 4                               Smokes        0.027233
# 5                       Smokes (years)        0.108667
# 6                  Smokes (packs/year)        0.636740
# 7              Hormonal Contraceptives        0.018852
# 8      Hormonal Contraceptives (years)        0.440836
# 9                                  IUD        0.060722
# 10                         IUD (years)        0.243695
# 11                                STDs        0.019165
# 12                       STDs (number)        0.029605
# 13                 STDs:condylomatosis        0.047465
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        0.460660
# 16  STDs:vulvo-perineal condylomatosis        0.046673
# 17                       STDs:syphilis        0.138247
# 18    STDs:pelvic inflammatory disease        2.215733
# 19                 STDs:genital herpes        2.138429
# 20          STDs:molluscum contagiosum        1.445423
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        0.105973
# 23                    STDs:Hepatitis B        1.993222
# 24                            STDs:HPV        1.003986
# 25           STDs: Number of diagnosis        0.008132
# 26    STDs: Time since first diagnosis        0.026587
# 27     STDs: Time since last diagnosis        0.028739
# 28                           Dx:Cancer        0.078293
# 29                              Dx:CIN        0.071491
# 30                              Dx:HPV        0.061166
# 31                                  Dx        0.078831
#
#     In-Dist Feature Impact  Native Feature Importance
# 0                 0.147631                   0.182038
# 1                 0.103377                   0.095739
# 2                 0.950142                   0.126344
# 3                 0.085121                   0.099572
# 4                 0.020229                   0.015186
# 5                 0.113428                   0.038859
# 6                 0.667902                   0.034416
# 7                 0.013371                   0.028101
# 8                 0.464178                   0.152612
# 9                 0.047943                   0.020013
# 10                0.278103                   0.039004
# 11                0.012595                   0.005317
# 12                0.028745                   0.011223
# 13                0.035012                   0.005940
# 14                0.000000                   0.000000
# 15                0.408568                   0.002241
# 16                0.033476                   0.005934
# 17                0.120525                   0.003466
# 18                1.967405                   0.001846
# 19                1.875109                   0.008268
# 20                1.283995                   0.001241
# 21                0.000000                   0.000000
# 22                0.085347                   0.012675
# 23                1.771206                   0.001566
# 24                0.891071                   0.002133
# 25                0.007531                   0.006080
# 26                0.028241                   0.019537
# 27                0.031178                   0.018307
# 28                0.016447                   0.017098
# 29                0.014645                   0.011415
# 30                0.012995                   0.016075
# 31                0.016501                   0.017753

# %%
comparator.build_normalized_table()
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age        1.157112
# 1            Number of sexual partners        0.795279
# 2             First sexual intercourse        6.794527
# 3                   Num of pregnancies        0.605071
# 4                               Smokes        0.214023
# 5                       Smokes (years)        0.853995
# 6                  Smokes (packs/year)        5.004023
# 7              Hormonal Contraceptives        0.148155
# 8      Hormonal Contraceptives (years)        3.464451
# 9                                  IUD        0.477206
# 10                         IUD (years)        1.915155
# 11                                STDs        0.150615
# 12                       STDs (number)        0.232658
# 13                 STDs:condylomatosis        0.373019
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        3.620238
# 16  STDs:vulvo-perineal condylomatosis        0.366791
# 17                       STDs:syphilis        1.086458
# 18    STDs:pelvic inflammatory disease       17.413035
# 19                 STDs:genital herpes       16.805514
# 20          STDs:molluscum contagiosum       11.359315
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        0.832824
# 23                    STDs:Hepatitis B       15.664362
# 24                            STDs:HPV        7.890141
# 25           STDs: Number of diagnosis        0.063907
# 26    STDs: Time since first diagnosis        0.208945
# 27     STDs: Time since last diagnosis        0.225856
# 28                           Dx:Cancer        0.615288
# 29                              Dx:CIN        0.561832
# 30                              Dx:HPV        0.480690
# 31                                  Dx        0.619514
#
#     In-Dist Feature Impact  Native Feature Importance
# 0                 1.280183                  18.203768
# 1                 0.896438                   9.573856
# 2                 8.239164                  12.634401
# 3                 0.738124                   9.957226
# 4                 0.175412                   1.518611
# 5                 0.983596                   3.885926
# 6                 5.791719                   3.441625
# 7                 0.115948                   2.810051
# 8                 4.025122                  15.261177
# 9                 0.415740                   2.001293
# 10                2.411572                   3.900357
# 11                0.109213                   0.531743
# 12                0.249263                   1.122310
# 13                0.303607                   0.594019
# 14                0.000000                   0.000000
# 15                3.542903                   0.224118
# 16                0.290287                   0.593364
# 17                1.045134                   0.346635
# 18               17.060369                   0.184616
# 19               16.260030                   0.826810
# 20               11.134178                   0.124097
# 21                0.000000                   0.000000
# 22                0.740090                   1.267482
# 23               15.359028                   0.156609
# 24                7.726928                   0.213341
# 25                0.065306                   0.608011
# 26                0.244892                   1.953689
# 27                0.270359                   1.830692
# 28                0.142622                   1.709829
# 29                0.126991                   1.141504
# 30                0.112689                   1.607520
# 31                0.143090                   1.775321
