# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="darkgrid")
import scipy as sp
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from datetime import datetime
import shap

# %%
exec(open("../../header.py").read())

# %% [markdown]
# # Import data

# %%
X = pd.read_csv(processed_root('cervical_cancer_risks/X.csv'))
y = pd.read_csv(processed_root('cervical_cancer_risks/y.csv'))

# %% [markdown]
# # Fit model

# %%
model = RandomForestClassifier(n_estimators = 500)
model.fit(X, y['Biopsy'])
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# # Comparison

# %%
exec(open("../../header.py").read())

# %%
shapley = SHAP_FI("tree")
native = Native_FI()
ice = ICE("binary")

fi_metrics = [ice, native, shapley]

# %%
comparator = Comparator(trace = True)

# %%
comparator.fit(X, model, fi_metrics)
# Out:
# Fitting for <__main__.ICE object at 0x000001E5BF0F94F0>
# Fitting for <__main__.Native_FI object at 0x000001E5C57B5B50>
# Fitting for <__main__.SHAP_FI object at 0x000001E5C57B5C70>
# List of shap values. Taking 2nd element.

# %% [markdown]
# # Results

# %%
comparator.build_raw_table()
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age        0.078107
# 1            Number of sexual partners        0.021049
# 2             First sexual intercourse        0.375499
# 3                   Num of pregnancies        0.034300
# 4                               Smokes        0.019769
# 5                       Smokes (years)        0.043882
# 6                  Smokes (packs/year)        0.140079
# 7              Hormonal Contraceptives        0.020119
# 8      Hormonal Contraceptives (years)        0.205680
# 9                                  IUD        0.037903
# 10                         IUD (years)        0.065455
# 11                                STDs        0.014485
# 12                       STDs (number)        0.010121
# 13                 STDs:condylomatosis        0.029485
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        0.075784
# 16  STDs:vulvo-perineal condylomatosis        0.021095
# 17                       STDs:syphilis        0.037918
# 18    STDs:pelvic inflammatory disease        0.139562
# 19                 STDs:genital herpes        0.108817
# 20          STDs:molluscum contagiosum        0.144074
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        0.027932
# 23                    STDs:Hepatitis B        0.123541
# 24                            STDs:HPV        0.119377
# 25           STDs: Number of diagnosis        0.002395
# 26    STDs: Time since first diagnosis        0.008264
# 27     STDs: Time since last diagnosis        0.007220
# 28                           Dx:Cancer        0.020515
# 29                              Dx:CIN        0.015612
# 30                              Dx:HPV        0.016025
# 31                                  Dx        0.026592
#
#     In-Dist Feature Impact  Native Feature Importance  Shapley Value
# 0                 0.080381                   0.180908       0.001316
# 1                 0.024171                   0.097514       0.000425
# 2                 0.431146                   0.125888       0.001021
# 3                 0.041793                   0.099226      -0.000440
# 4                 0.026150                   0.013649       0.000086
# 5                 0.048187                   0.038101       0.000274
# 6                 0.149950                   0.034880       0.000007
# 7                 0.019379                   0.028764      -0.000882
# 8                 0.222981                   0.152777      -0.001437
# 9                 0.052893                   0.020891       0.000703
# 10                0.078066                   0.038667       0.000108
# 11                0.017873                   0.005370       0.000239
# 12                0.012098                   0.011671      -0.000440
# 13                0.041775                   0.006170       0.000167
# 14                0.000000                   0.000000       0.000000
# 15                0.120899                   0.002552       0.000116
# 16                0.026915                   0.005807      -0.000002
# 17                0.059288                   0.003532      -0.000114
# 18                0.223146                   0.001393      -0.000070
# 19                0.170748                   0.009379      -0.000277
# 20                0.230432                   0.001361       0.000122
# 21                0.000000                   0.000000       0.000000
# 22                0.039360                   0.011002      -0.000114
# 23                0.197451                   0.001567       0.000108
# 24                0.190799                   0.001825       0.000160
# 25                0.003522                   0.006384       0.000636
# 26                0.009541                   0.019180       0.000316
# 27                0.008146                   0.019611       0.000290
# 28                0.020140                   0.015723      -0.000331
# 29                0.015426                   0.011552      -0.000384
# 30                0.015946                   0.016463      -0.000384
# 31                0.025767                   0.018194      -0.000260

# %%
comparator.build_normalized_table()
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age        3.923695
# 1            Number of sexual partners        1.057399
# 2             First sexual intercourse       18.863088
# 3                   Num of pregnancies        1.723068
# 4                               Smokes        0.993104
# 5                       Smokes (years)        2.204391
# 6                  Smokes (packs/year)        7.036823
# 7              Hormonal Contraceptives        1.010692
# 8      Hormonal Contraceptives (years)       10.332258
# 9                                  IUD        1.904024
# 10                         IUD (years)        3.288098
# 11                                STDs        0.727641
# 12                       STDs (number)        0.508417
# 13                 STDs:condylomatosis        1.481175
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        3.806998
# 16  STDs:vulvo-perineal condylomatosis        1.059719
# 17                       STDs:syphilis        1.904791
# 18    STDs:pelvic inflammatory disease        7.010875
# 19                 STDs:genital herpes        5.466380
# 20          STDs:molluscum contagiosum        7.237530
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        1.403137
# 23                    STDs:Hepatitis B        6.206048
# 24                            STDs:HPV        5.996846
# 25           STDs: Number of diagnosis        0.120312
# 26    STDs: Time since first diagnosis        0.415155
# 27     STDs: Time since last diagnosis        0.362670
# 28                           Dx:Cancer        1.030563
# 29                              Dx:CIN        0.784246
# 30                              Dx:HPV        0.805036
# 31                                  Dx        1.335823
#
#     In-Dist Feature Impact  Native Feature Importance  Shapley Value
# 0                 3.086407                  18.090793      11.717033
# 1                 0.928102                   9.751372       3.787086
# 2                16.554723                  12.588784       9.092194
# 3                 1.604731                   9.922644      -3.921222
# 4                 1.004069                   1.364942       0.767296
# 5                 1.850251                   3.810074       2.435761
# 6                 5.757642                   3.487983       0.066443
# 7                 0.744097                   2.876374      -7.853187
# 8                 8.561818                  15.277674     -12.791439
# 9                 2.030925                   2.089097       6.263340
# 10                2.997485                   3.866740       0.960802
# 11                0.686270                   0.536966       2.131280
# 12                0.464514                   1.167063      -3.914652
# 13                1.604032                   0.616981       1.488418
# 14                0.000000                   0.000000       0.000000
# 15                4.642162                   0.255225       1.031179
# 16                1.033461                   0.580738      -0.020982
# 17                2.276481                   0.353164      -1.011567
# 18                8.568148                   0.139258      -0.625525
# 19                6.556220                   0.937921      -2.466503
# 20                8.847898                   0.136104       1.084958
# 21                0.000000                   0.000000       0.000000
# 22                1.511301                   1.100160      -1.017298
# 23                7.581509                   0.156672       0.965512
# 24                7.326101                   0.182481       1.428802
# 25                0.135243                   0.638440       5.660652
# 26                0.366337                   1.918032       2.817625
# 27                0.312778                   1.961083       2.585077
# 28                0.773329                   1.572309      -2.943856
# 29                0.592318                   1.155219      -3.417313
# 30                0.612276                   1.646315      -3.414661
# 31                0.989374                   1.819391      -2.318337
