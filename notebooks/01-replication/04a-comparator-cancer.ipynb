# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_theme(style="darkgrid")
import scipy as sp
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from datetime import datetime
import shap

# %%
exec(open("../../header.py").read())

# %% [markdown]
# # Import data

# %%
X = pd.read_csv(processed_root('cervical_cancer_risks/X.csv'))
y = pd.read_csv(processed_root('cervical_cancer_risks/y.csv'))

# %% [markdown]
# # Fit model

# %%
model = RandomForestClassifier(n_estimators = 500)
model.fit(X, y['Biopsy'])
# Out:
# RandomForestClassifier(n_estimators=500)

# %% [markdown]
# # Comparison

# %%
exec(open("../../header.py").read())

# %%
shapley = SHAP_FI("tree")
native = Native_FI()
ice = ICE("binary")
pfi = PFI_FI()

fi_metrics = [ice, native, shapley, pfi]

# %%
comparator = Comparator(trace = True)

# %%
comparator.fit(X, model, fi_metrics)
# Out:
# Fitting for <__main__.ICE object at 0x7f9ba2af3310>
# Fitting for <__main__.Native_FI object at 0x7f9ba2af3be0>
# Fitting for <__main__.SHAP_FI object at 0x7f9ba2af3c70>
# List of shap values. Taking 2nd element.
# Fitting for <__main__.PFI_FI object at 0x7f9ba2af3b20>
# PFI fits in 24.86 seconds

# %% [markdown]
# # Results

# %%
comparator.build_raw_table()
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age        0.075382
# 1            Number of sexual partners        0.021675
# 2             First sexual intercourse        0.414912
# 3                   Num of pregnancies        0.033787
# 4                               Smokes        0.025273
# 5                       Smokes (years)        0.036884
# 6                  Smokes (packs/year)        0.192940
# 7              Hormonal Contraceptives        0.018899
# 8      Hormonal Contraceptives (years)        0.209001
# 9                                  IUD        0.036263
# 10                         IUD (years)        0.074189
# 11                                STDs        0.011254
# 12                       STDs (number)        0.007677
# 13                 STDs:condylomatosis        0.017537
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        0.094676
# 16  STDs:vulvo-perineal condylomatosis        0.018633
# 17                       STDs:syphilis        0.027818
# 18    STDs:pelvic inflammatory disease        0.162971
# 19                 STDs:genital herpes        0.130111
# 20          STDs:molluscum contagiosum        0.133118
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        0.036114
# 23                    STDs:Hepatitis B        0.165594
# 24                            STDs:HPV        0.113003
# 25           STDs: Number of diagnosis        0.001956
# 26    STDs: Time since first diagnosis        0.007348
# 27     STDs: Time since last diagnosis        0.006119
# 28                           Dx:Cancer        0.020823
# 29                              Dx:CIN        0.014791
# 30                              Dx:HPV        0.015909
# 31                                  Dx        0.025958
#
#     In-Dist Feature Impact  Native Feature Importance  Shapley Value       PFI
# 0                 0.077629                   0.179120       0.001837  0.030886
# 1                 0.024901                   0.100697       0.000776  0.023543
# 2                 0.477193                   0.123726       0.000796  0.026923
# 3                 0.041188                   0.100269      -0.000224  0.029837
# 4                 0.033640                   0.013947       0.000084  0.004545
# 5                 0.038570                   0.040451       0.000522  0.009790
# 6                 0.206612                   0.034873      -0.000437  0.008508
# 7                 0.018148                   0.025867      -0.001084  0.011305
# 8                 0.225044                   0.155250      -0.001375  0.033566
# 9                 0.051094                   0.020738       0.000279  0.004196
# 10                0.088466                   0.038761       0.000367  0.010373
# 11                0.012908                   0.005488       0.000063  0.001282
# 12                0.009382                   0.009793       0.000095  0.002564
# 13                0.021813                   0.005930      -0.000121  0.001166
# 14                0.000000                   0.000000       0.000000  0.000000
# 15                0.151144                   0.002333       0.000372  0.000000
# 16                0.022605                   0.006598      -0.000162  0.002214
# 17                0.043447                   0.003599       0.000251  0.000000
# 18                0.260427                   0.001837       0.000146  0.000000
# 19                0.204668                   0.009211      -0.000269  0.001166
# 20                0.212727                   0.001580       0.000106  0.000000
# 21                0.000000                   0.000000       0.000000  0.000000
# 22                0.051611                   0.012317       0.000020  0.004196
# 23                0.264740                   0.001632       0.000400  0.000000
# 24                0.180640                   0.001742       0.000017  0.000000
# 25                0.002953                   0.006600       0.000430  0.000000
# 26                0.008258                   0.017836       0.000236  0.000117
# 27                0.006965                   0.018050       0.000065  0.000000
# 28                0.020479                   0.016252      -0.000324  0.003380
# 29                0.014643                   0.012084      -0.000451  0.001282
# 30                0.015878                   0.015942      -0.000436  0.002331
# 31                0.025177                   0.017477      -0.000269  0.002448

# %%
comparator.build_normalized_table()
# Out:
#                                Feature  Feature Impact  \
# 0                                  Age        3.505148
# 1            Number of sexual partners        1.007834
# 2             First sexual intercourse       19.292717
# 3                   Num of pregnancies        1.571048
# 4                               Smokes        1.175167
# 5                       Smokes (years)        1.715021
# 6                  Smokes (packs/year)        8.971383
# 7              Hormonal Contraceptives        0.878794
# 8      Hormonal Contraceptives (years)        9.718176
# 9                                  IUD        1.686174
# 10                         IUD (years)        3.449654
# 11                                STDs        0.523270
# 12                       STDs (number)        0.356969
# 13                 STDs:condylomatosis        0.815456
# 14        STDs:cervical condylomatosis        0.000000
# 15         STDs:vaginal condylomatosis        4.402268
# 16  STDs:vulvo-perineal condylomatosis        0.866424
# 17                       STDs:syphilis        1.293512
# 18    STDs:pelvic inflammatory disease        7.577872
# 19                 STDs:genital herpes        6.049952
# 20          STDs:molluscum contagiosum        6.189766
# 21                           STDs:AIDS        0.000000
# 22                            STDs:HIV        1.679237
# 23                    STDs:Hepatitis B        7.699827
# 24                            STDs:HPV        5.254455
# 25           STDs: Number of diagnosis        0.090928
# 26    STDs: Time since first diagnosis        0.341649
# 27     STDs: Time since last diagnosis        0.284543
# 28                           Dx:Cancer        0.968242
# 29                              Dx:CIN        0.687764
# 30                              Dx:HPV        0.739750
# 31                                  Dx        1.206999
#
#     In-Dist Feature Impact  Native Feature Importance  Shapley Value  \
# 0                 2.759704                  17.911977      15.294398
# 1                 0.885225                  10.069724       6.461161
# 2                16.964151                  12.372622       6.625800
# 3                 1.464222                  10.026906      -1.862684
# 4                 1.195891                   1.394703       0.695678
# 5                 1.371156                   4.045093       4.342855
# 6                 7.345025                   3.487269      -3.640085
# 7                 0.645143                   2.586711      -9.022729
# 8                 8.000295                  15.525014     -11.449104
# 9                 1.816396                   2.073820       2.322382
# 10                3.144942                   3.876071       3.051188
# 11                0.458882                   0.548830       0.523477
# 12                0.333528                   0.979271       0.794946
# 13                0.775447                   0.593041      -1.004871
# 14                0.000000                   0.000000       0.000000
# 15                5.373148                   0.233323       3.093839
# 16                0.803593                   0.659781      -1.350397
# 17                1.544542                   0.359934       2.091599
# 18                9.258142                   0.183689       1.215164
# 19                7.275934                   0.921062      -2.240318
# 20                7.562427                   0.157995       0.883871
# 21                0.000000                   0.000000       0.000000
# 22                1.834766                   1.231669       0.169019
# 23                9.411465                   0.163196       3.330354
# 24                6.421742                   0.174151       0.137493
# 25                0.104989                   0.660006       3.577496
# 26                0.293556                   1.783589       1.961890
# 27                0.247593                   1.805037       0.537555
# 28                0.728038                   1.625231      -2.699282
# 29                0.520562                   1.208396      -3.756294
# 30                0.564460                   1.594161      -3.627958
# 31                0.895039                   1.747729      -2.236113
#
#           PFI
# 0   14.324324
# 1   10.918919
# 2   12.486486
# 3   13.837838
# 4    2.108108
# 5    4.540541
# 6    3.945946
# 7    5.243243
# 8   15.567568
# 9    1.945946
# 10   4.810811
# 11   0.594595
# 12   1.189189
# 13   0.540541
# 14   0.000000
# 15   0.000000
# 16   1.027027
# 17   0.000000
# 18   0.000000
# 19   0.540541
# 20   0.000000
# 21   0.000000
# 22   1.945946
# 23   0.000000
# 24   0.000000
# 25   0.000000
# 26   0.054054
# 27   0.000000
# 28   1.567568
# 29   0.594595
# 30   1.081081
# 31   1.135135
